# %% [markdown]
# ## Data preparation

# %% [markdown]
# This dataset contains ESC final results from 1956 to 2019.
#
# This notebook cleans the data and replaces categorical values with numeric ones.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read in data from csv file

# %%
data = pd.read_csv("../data/ESCDB2.csv", sep=";", encoding="UTF-8")

# Removing potential unneccesary spaces from dataframe columns
for column in data.select_dtypes(include='object'):
    data[column] = data[column].str.strip()

# Dropping duplicate column "songid"
data.drop('songid', axis=1)
# Out:
#       song_id  Year  Order      Country                     Singer  \
# 0           1  1956      1  Netherlands                Jetty Paerl
# 1           2  1956      2  Switzerland                  Lys Assia
# 2           3  1956      3      Belgium                Fud Leclerc
# 3           4  1956      4      Germany     Walter Andreas Schwarz
# 4           5  1956      5       France               Mathé Altéry
# ...       ...   ...    ...          ...                        ...
# 1312     1329  2019     33       Poland                      Tulia
# 1313     1331  2019     35      Romania                Ester Peony
# 1314     1333  2019     37       Russia             Sergey Lazarev
# 1315     1335  2019     39     Slovenia  Zala Kralj & Gašper Šantl
# 1316     1337  2019     41       France              Bilal Hassani
#
#                                   Title  Points  Place  in_english  \
# 0                 De Vogels Van Holland     0.0    0.0       False
# 1                     Das Alte Karussel     0.0    0.0       False
# 2     Messieurs Les Noyés Dans La Seine     0.0    0.0       False
# 3             Das Lied Vom Großen Glück     0.0    0.0       False
# 4                        Le Temps Perdu     0.0    0.0       False
# ...                                 ...     ...    ...         ...
# 1312                       Fire of Love     NaN    NaN       False
# 1313                        On a Sunday     NaN    NaN        True
# 1314                             Scream     NaN    NaN        True
# 1315                               Sebi     NaN    NaN       False
# 1316                                Roi     NaN    NaN       False
#
#       lovementions  population
# 0              0.0  17000000.0
# 1              0.0   8420000.0
# 2              4.0  11350000.0
# 3              0.0  82790000.0
# 4              6.0  67120000.0
# ...            ...         ...
# 1312    37970000.0         NaN
# 1313    19640000.0         NaN
# 1314   144500000.0         NaN
# 1315     1990000.0         NaN
# 1316    67120000.0         NaN
#
# [1317 rows x 11 columns]

# %% [markdown]
# Making country column numeric

# %%
countries = data["Country"].unique()
countries.sort()
countries

countries_to_numbers = {}

for i in range(len(countries)):
    countries_to_numbers[countries[i]] = i

data["Country"] = data["Country"].map(countries_to_numbers)

# %% [markdown]
# Making the singer column numeric
#
# This will be a boolean value:
# * **0** if the singer has only performed once in ESC
# * **1** if the singer has performed multiple times in ESC

# %%
data["Singer"] = data["Singer"].map(lambda x: 0 if data["Singer"].value_counts()[x] == 1 else 1)

# %% [markdown]
# Making title column numeric.
#
# We are extracting two attributes:
# * 1 if song title included word "Love" 0 otherwise
# * 1 if song title is more than 1 word, 0 otherwise

# %%
data["love_in_title"] = data["Title"].map(lambda x: 1 if 'love' in x.lower() else 0)

# %%
data["Title"] = data["Title"].map(lambda x: len(x.split()))
data = data.rename(columns={"Title" : "title_word_count"})

# %% [markdown]
# Making "in_english" column numeric.

# %%
data["in_english"] = data["in_english"].map(lambda x: 1 if x else 0)

# %%
# display out the result
data
# Out:
#       song_id  Year  Order  Country  Singer  title_word_count  Points  Place  \
# 0           1  1956      1       33       0                 4     0.0    0.0
# 1           2  1956      2       46       1                 3     0.0    0.0
# 2           3  1956      3        6       1                 6     0.0    0.0
# 3           4  1956      4       17       0                 5     0.0    0.0
# 4           5  1956      5       15       0                 3     0.0    0.0
# ...       ...   ...    ...      ...     ...               ...     ...    ...
# 1312     1329  2019     33       35       0                 3     NaN    NaN
# 1313     1331  2019     35       37       0                 3     NaN    NaN
# 1314     1333  2019     37       38       1                 1     NaN    NaN
# 1315     1335  2019     39       43       0                 1     NaN    NaN
# 1316     1337  2019     41       15       0                 1     NaN    NaN
#
#       in_english  songid  lovementions  population  love_in_title
# 0              0     1.0           0.0  17000000.0              0
# 1              0     2.0           0.0   8420000.0              0
# 2              0     3.0           4.0  11350000.0              0
# 3              0     4.0           0.0  82790000.0              0
# 4              0     5.0           6.0  67120000.0              0
# ...          ...     ...           ...         ...            ...
# 1312           0     NaN    37970000.0         NaN              1
# 1313           1     NaN    19640000.0         NaN              0
# 1314           1     NaN   144500000.0         NaN              0
# 1315           0     NaN     1990000.0         NaN              0
# 1316           0     NaN    67120000.0         NaN              0
#
# [1317 rows x 13 columns]
